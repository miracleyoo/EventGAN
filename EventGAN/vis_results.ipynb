# %%
import os
import sys
import torch
import torch.nn as nn
import numpy as np
import pickle as pkl
import matplotlib.pyplot as plt

# Automatically reload external modules
# %load_ext autoreload
# %autoreload 2

# %%
path = '/tsukimi/backup/EventGAN-pretrained-model-test-results-retrained/indoor_flying3_data_left-140.pkl'
res = pkl.load(open(path, 'rb'))

# %%
res.keys()
# Out:
# dict_keys(['gt_event_volume', 'gen_event_volume', 'metrics'])

# %%
gt_ef = res['gt_event_volume'][0]
gt_ef = gt_ef.sum(axis=0)
gen_ef = res['gen_event_volume'][0]
gen_ef = gen_ef.sum(axis=0)

# %%
gen_ef.shape
# Out:
# (260, 346)

# %%
# Plot the ground truth event volume
plt.figure(figsize=(10, 10))
plt.imshow(gt_ef, cmap='gray')
plt.title('Ground Truth Event Volume')
plt.show()

# Plot the generated event volume
plt.figure(figsize=(10, 10))
plt.imshow(gen_ef, cmap='gray')
plt.title('Generated Event Volume')
plt.show()
